# %%
import pickle
from sklearn.model_selection import KFold
import xgboost as xgb
import numpy as np
kf = KFold(5,shuffle=True,random_state=42)
from sklearn.base import clone
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import seaborn as sns

import matplotlib as mpl
mpl.rc("savefig", dpi=100)

# %%
valenceLabelsFolder = 'Dataset/valenceLabels.dat'
with open(valenceLabelsFolder,'rb') as f:
  valenceLabels = pickle.load(f)

# %%
arousalLabelsFolder = 'Dataset/arousalLabels.dat'
with open(arousalLabelsFolder,'rb') as f:
  arousalLabels = pickle.load(f)

# %%
StatisticalFeaturesFolder = 'Dataset/statisticalFeatures.dat'
with open(StatisticalFeaturesFolder,'rb') as f:
  statisticalFeatures = pickle.load(f)

# %%
fdFeaturesFolder = 'Dataset/fdFeatures.dat'
with open(fdFeaturesFolder,'rb') as f:
  fdFeatures = pickle.load(f)

# %%
powerFeaturesFolder = 'Dataset/powerFeatures.dat'
with open(powerFeaturesFolder,'rb') as f:
  powerFeatures = pickle.load(f)

# %%
waveletFeaturesFolder = 'Dataset/powerFeatures.dat'
with open(waveletFeaturesFolder,'rb') as f:
  waveletFeatures = pickle.load(f)

# %%
features = np.dstack(statisticalFeatures,fdFeatures,powerFeatures,waveletFeatures)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/pb/4t256kf1739f02pn7ldh71lw0000gn/T/ipykernel_9403/3859375386.py in <module>
# ----> 1 features = np.dstack(statisticalFeatures,fdFeatures,powerFeatures,waveletFeatures)
#
# <__array_function__ internals> in dstack(*args, **kwargs)
#
# TypeError: _dstack_dispatcher() takes 1 positional argument but 4 were given
